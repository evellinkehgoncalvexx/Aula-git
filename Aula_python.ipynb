# %% [markdown]
# <a href="https://colab.research.google.com/github/evellinkehgoncalvexx/Aula-git/blob/main/Aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
meu_nome = "Evellin"
idade = 16
print(meu_nome)
print("Meu nome é:", meu_nome)
print(f"Meu nome é {meu_nome} eu tenho {idade} anos.")
# Out:
# Evellin
# Meu nome é: Evellin
# Meu nome é Evellin eu tenho 16 anos.

# %% [markdown]
# Comandos de Saída

# %%
meu_nome = "Evellin"
idade = 16
nome_mae = "Claudia"
idade_mae = 48
nome_pai = "Claudio"
idade_pai = 52
meu_curso = "DS"

print(f"Meu nome é {meu_nome} eu tenho {idade} anos e faço {meu_curso}." )
print(f"Minha mãe se chama {nome_mae} ela tem {idade_mae} anos.")
print(f"Meu pai se chama {nome_pai} e ele tem {idade_pai} anos.")
# Out:
# Meu nome é Evellin eu tenho 16 anos e faço DS.
# Minha mãe se chama Claudia ela tem 48 anos.
# Meu pai se chama Claudio e ele tem 52 anos.

# %% [markdown]
# Comando de Entrada

# %%
curso = input("Qual o curso que você faz?")
print(f"Oh! Você faz {curso}! Que legal!!")
# Out:
# Qual o curso que você faz?DS
# Oh! Você faz DS! Que legal!!

# %%
Nome = input("Qual o seu nome? ")
idade = input("Qual a sua idade? ")
print(f"Oh! {Nome} é lindo!! {idade}?? Bem nova ainda.")
# Out:
# Qual o seu nome? Evellin
# Qual a sua idade? 16
# Oh! Evellin é lindo!! 16?? Bem nova ainda.

# %%
numero1 =  input("Digite um n")
numero2 = 20

print(numero1 / numero2)
# Out:
# 5.0
